# %%
# Importar librerias pandas, numpy, matpltlib y seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/spamella04/InteligenciadeNegocios2024/refs/heads/IvaChavarria/ClasePractica1/public-health-statistics-selected-public-health-indicators-by-chicago-community-area-1.csv'
df=pd.read_csv(url)
df.head()
# Out:
#    index  Community Area Community Area Name  Birth Rate  \
# 0      0               1         Rogers Park        16.4
# 1      1               2          West Ridge        17.3
# 2      2               3              Uptown        13.1
# 3      3               4      Lincoln Square        17.1
# 4      4               5        North Center        22.4
#
#    General Fertility Rate  Low Birth Weight  \
# 0                    62.0              11.0
# 1                    83.3               8.1
# 2                    50.5               8.3
# 3                    61.0               8.1
# 4                    76.2               9.1
#
#    Prenatal Care Beginning in First Trimester  Preterm Births  \
# 0                                        73.0            11.2
# 1                                        71.1             8.3
# 2                                        77.7            10.3
# 3                                        80.5             9.7
# ...

# %%
df.fillna(0, inplace=True)

# %%
df_numerico = df.select_dtypes(include=['float64', 'int64'])

# %%
media = df_numerico.mean()
print(media)
# Out:
# index                                            38.000000
# Community Area                                   39.000000
# Birth Rate                                       15.698701
# General Fertility Rate                           68.394805
# Low Birth Weight                                 10.101299
# Prenatal Care Beginning in First Trimester       76.954545
# Preterm Births                                   11.264935
# Teen Birth Rate                                  50.064935
# Assault (Homicide)                               18.068831
# Breast cancer in females                         25.951948
# Cancer (All Sites)                              194.277922
# Colorectal Cancer                                21.584416
# Diabetes-related                                 71.937662
# Firearm-related                                  16.731169
# Infant Mortality Rate                             8.574026
# Lung Cancer                                      51.481818
# ...

# %%
media.plot(kind='bar', figsize=(10, 6))
plt.title('Media de las columnas')
plt.ylabel('Media')
plt.xticks(rotation=90)
plt.show()

# %%
media_sin_per_capita = media.drop('Per Capita Income')
media_sin_per_capita.plot(kind='bar', figsize=(10, 6))
plt.title('Media de las columnas sin Per Capita Income')
plt.ylabel('Media')
plt.xticks(rotation=90)
plt.show()

# %%
mediana = df_numerico.median()
print(mediana)
# Out:
# index                                            38.0
# Community Area                                   39.0
# Birth Rate                                       15.7
# General Fertility Rate                           68.3
# Low Birth Weight                                  8.7
# Prenatal Care Beginning in First Trimester       76.1
# Preterm Births                                   10.8
# Teen Birth Rate                                  49.2
# Assault (Homicide)                               10.8
# Breast cancer in females                         24.0
# Cancer (All Sites)                              189.4
# Colorectal Cancer                                21.9
# Diabetes-related                                 73.0
# Firearm-related                                  10.6
# Infant Mortality Rate                             8.1
# Lung Cancer                                      50.0
# Prostate Cancer in Males                         32.1
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_numerico)
plt.title('Distribución de variables numéricas de Salud Pública')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_numerico.drop('Per Capita Income', axis=1))
plt.title('Distribución de Variables Numéricas de Salud Pública (sin Per Capita Income)')
plt.xticks(rotation=90)
plt.show()

# %%
desviacion_estandard = df_numerico.std()
print(desviacion_estandard)
# Out:
# index                                            22.371857
# Community Area                                   22.371857
# Birth Rate                                        3.528735
# General Fertility Rate                           15.257465
# Low Birth Weight                                  3.913926
# Prenatal Care Beginning in First Trimester        5.245714
# Preterm Births                                    3.016916
# Teen Birth Rate                                  28.097817
# Assault (Homicide)                               16.561077
# Breast cancer in females                          9.557590
# Cancer (All Sites)                               45.652058
# Colorectal Cancer                                 7.695335
# Diabetes-related                                 21.497999
# Firearm-related                                  14.462222
# Infant Mortality Rate                             4.408765
# Lung Cancer                                      16.439928
# ...

# %%
desviacion_estandard.plot(kind='bar', figsize=(10, 6))
plt.title('Desviación Estándar de Salud Pública')
plt.ylabel('Desviación Estándar')
plt.xticks(rotation=90)
plt.show()

# %%
desviacion_estandar_sin_per_capita = desviacion_estandard.drop('Per Capita Income')
desviacion_estandar_sin_per_capita.plot(kind='bar', figsize=(10, 6))
plt.title('Desviación Estándar de Variables Numéricas (sin Per Capita Income)')
plt.ylabel('Desviación Estándar')
plt.xticks(rotation=90)
plt.show()

# %%
minimo = df_numerico.min()
print(minimo)
# Out:
# index                                            0.0
# Community Area                                   1.0
# Birth Rate                                       9.4
# General Fertility Rate                          27.7
# Low Birth Weight                                 3.5
# Prenatal Care Beginning in First Trimester      63.6
# Preterm Births                                   5.0
# Teen Birth Rate                                  1.3
# Assault (Homicide)                               0.0
# Breast cancer in females                         7.6
# Cancer (All Sites)                             120.1
# Colorectal Cancer                                8.6
# Diabetes-related                                26.8
# Firearm-related                                  1.0
# Infant Mortality Rate                            1.5
# Lung Cancer                                     15.9
# Prostate Cancer in Males                         0.0
# Stroke (Cerebrovascular Disease)                22.0
# ...

# %%
minimo.plot(kind='bar', figsize=(10, 6))
plt.title('Valor Mínimo de Variables Numéricas de Salud Pública')
plt.ylabel('Valor Mínimo')
plt.xticks(rotation=90)
plt.show()

# %%
minimo_sin_per_capita = minimo.drop('Per Capita Income')
minimo_sin_per_capita.plot(kind='bar', figsize=(10, 6))
plt.title('Valor Mínimo de Variables Numéricas (sin Per Capita Income)')
plt.ylabel('Valor Mínimo')
plt.xticks(rotation=90)
plt.show()

# %%
maximo = df_numerico.max()
print(maximo)
# Out:
# index                                            76.0
# Community Area                                   77.0
# Birth Rate                                       22.4
# General Fertility Rate                           94.9
# Low Birth Weight                                 19.7
# Prenatal Care Beginning in First Trimester       94.5
# Preterm Births                                   17.5
# Teen Birth Rate                                 116.9
# Assault (Homicide)                               70.3
# Breast cancer in females                         54.7
# Cancer (All Sites)                              291.5
# Colorectal Cancer                                39.4
# Diabetes-related                                119.1
# Firearm-related                                  70.3
# Infant Mortality Rate                            22.6
# Lung Cancer                                      89.6
# Prostate Cancer in Males                         92.9
# ...

# %%
maximo = df_numerico.max()
maximo.plot(kind='bar', figsize=(10, 6))
plt.title('Valor Máximo de Variables Numéricas de Salud Pública')
plt.ylabel('Valor Máximo')
plt.xticks(rotation=90)
plt.show()

# %%
maximo_sin_per_capita = maximo.drop('Per Capita Income')
maximo_sin_per_capita.plot(kind='bar', figsize=(10, 6))
plt.title('Valor Máximo de Variables Numéricas (sin Per Capita Income)')
plt.ylabel('Valor Máximo')
plt.xticks(rotation=90)
plt.show()

# %%
correlacion = df_numerico.corr()
print(correlacion)
# Out:
#                                                index  Community Area  \
# index                                       1.000000        1.000000
# Community Area                              1.000000        1.000000
# Birth Rate                                  0.030501        0.030501
# General Fertility Rate                      0.222777        0.222777
# Low Birth Weight                            0.155770        0.155770
# Prenatal Care Beginning in First Trimester -0.005931       -0.005931
# Preterm Births                              0.226277        0.226277
# Teen Birth Rate                             0.250163        0.250163
# Assault (Homicide)                          0.345811        0.345811
# Breast cancer in females                    0.300842        0.300842
# Cancer (All Sites)                          0.361057        0.361057
# Colorectal Cancer                           0.218365        0.218365
# Diabetes-related                            0.240273        0.240273
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlacion, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlación de Variables Numéricas de Salud Pública')
plt.show()
